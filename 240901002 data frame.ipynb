# %%
import pandas as pd
import numpy as np
df=pd.DataFrame(np.random.randn(4,3), index=['a','c','d','f'],
columns=['one','two','three'])
df = df.reindex(['a','b','c','d','e','f'])
print("Original Dataframe with NaN\n",df)
print("\n")
print("Dropped DataFrame\n",df.dropna())
print("\n")
# Out:
# Original Dataframe with NaN
#          one       two     three
# a -0.487958 -1.051971 -0.951711
# b       NaN       NaN       NaN
# c  1.297654  1.064700 -0.376855
# d  1.229493 -0.919678  0.390478
# e       NaN       NaN       NaN
# f  0.538470 -0.827684  0.156445
#
#
# Dropped DataFrame
#          one       two     three
# a -0.487958 -1.051971 -0.951711
# c  1.297654  1.064700 -0.376855
# d  1.229493 -0.919678  0.390478
# f  0.538470 -0.827684  0.156445

# %%
df=pd.DataFrame(np.random.randn(4,3), index=['a','c','d','f'],
columns=['one','two','three'])
df = df.reindex(['a','b','c'])
print("Original Dataframe:\n",df)
print("\n")
print("NaN replaced with '0':\n")
print(df.fillna(0))
# Out:
# Original Dataframe:
#          one       two     three
# a  0.366080 -1.577817 -0.451778
# b       NaN       NaN       NaN
# c  0.207348  1.275771 -0.303152
#
#
# NaN replaced with '0':
#
#         one       two     three
# a  0.366080 -1.577817 -0.451778
# b  0.000000  0.000000  0.000000
# c  0.207348  1.275771 -0.303152

# %%
df=pd.DataFrame({'one':[10,20,80,40,50],
'two':[60,70,80,0,10]})
print("Original Dataframe:\n",df)
print("\n DataFrame with replaced values:\n")
print(df.replace({10:5,80:3}))
# Out:
# Original Dataframe:
#     one  two
# 0   10   60
# 1   20   70
# 2   80   80
# 3   40    0
# 4   50   10
#
#  DataFrame with replaced values:
#
#    one  two
# 0    5   60
# 1   20   70
# 2    3    3
# 3   40    0
# 4   50    5

# %%
df=pd.DataFrame(np.random.randn(4,3), index=['a','c','d','f'],
columns=['one','two','three'])
df = df.reindex(['a','b','c','d','e','f'])
print("Original Dataframe:\n",df)
print("\nNan-with True fill:\n")
print(df['one'].isnull())
# Out:
# Original Dataframe:
#          one       two     three
# a  2.129339 -0.095541  0.574101
# b       NaN       NaN       NaN
# c -0.040713 -0.104917 -1.056344
# d -0.368764 -0.726670 -0.618907
# e       NaN       NaN       NaN
# f  0.832094  1.174431 -1.182304
#
# Nan-with True fill:
#
# a    False
# b     True
# c    False
# d    False
# e     True
# f    False
# Name: one, dtype: bool

# %%
df=pd.DataFrame(np.random.randn(4,3), index=['a','c','d','f'],
columns=['one','two','three'])
df = df.reindex(['a','b','c','d','e','f'])
print("Original Dataframe:\n",df)
print("\nNaN - Filled with Background values:\n")
print(df.fillna(method='bfill'))
# Out:
# Original Dataframe:
#          one       two     three
# a  1.997529 -0.646016  0.269062
# b       NaN       NaN       NaN
# c -0.439223 -0.296137  0.887444
# d -0.745110  0.101066 -0.048316
# e       NaN       NaN       NaN
# f  0.868823  0.005983  0.458814
#
# NaN - Filled with Background values:
#
#         one       two     three
# a  1.997529 -0.646016  0.269062
# b -0.439223 -0.296137  0.887444
# c -0.439223 -0.296137  0.887444
# d -0.745110  0.101066 -0.048316
# e  0.868823  0.005983  0.458814
# f  0.868823  0.005983  0.458814
